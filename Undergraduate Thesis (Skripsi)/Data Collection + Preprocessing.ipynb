# %%
from spotipy.oauth2 import SpotifyClientCredentials
import json
import spotipy
import time
import sys

from tqdm.notebook import tqdm
import pandas as pd
import numpy as np
import os
from time import sleep

# %% [markdown]
# # Data Collection

# %%
SPOTIPY_CLIENT_ID=''
SPOTIPY_CLIENT_SECRET=''

#ID and Secret needs to be filled with your own Spotify Developer credentials
#In this file, the credentials are being removed for privacy reasons

client_credentials_manager = SpotifyClientCredentials(client_id=SPOTIPY_CLIENT_ID, client_secret=SPOTIPY_CLIENT_SECRET)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
ranking_features_df= pd.read_csv(('regional-global-weekly-2023-05-18.csv'), index_col=0)
ranking_features_df.head()
# Out:
#                                        uri                artist_names  \
# rank
# 1     spotify:track:3qQbCzHBycnDpGskqOWY0E  Eslabon Armado, Peso Pluma
# 2     spotify:track:6pD0ufEQq0xdHSsRbg9LBK   Grupo Frontera, Bad Bunny
# 3     spotify:track:2UW7JaomAMuX9pZrjVpHAU       Yng Lvcas, Peso Pluma
# 4     spotify:track:7FbrGaHYVDmfr7KoLIZnQ7                 FIFTY FIFTY
# 5     spotify:track:4DHcnVTT87F0zZhRPYmZ3B                 Miley Cyrus
#
#              track_name                    source  peak_rank  previous_rank  \
# rank
# 1       Ella Baila Sola               DEL Records          1              2
# 2             un x100to  Rimas Entertainment LLC.          1              1
# 3       La Bebe - Remix                 WM Mexico          3              3
# 4     Cupid - Twin Ver.                  WM Korea          4              4
# 5               Flowers                  Columbia          1              5
#
#       weeks_on_chart   streams
# rank
# ...

# %%
import glob
 
# list all csv files only
csv_files = glob.glob('*.{}'.format('csv'))
csv = sorted(csv_files)
csv
# Out:
# ['regional-global-weekly-2017-01-05.csv',
#  'regional-global-weekly-2017-01-12.csv',
#  'regional-global-weekly-2017-01-19.csv',
#  'regional-global-weekly-2017-01-26.csv',
#  'regional-global-weekly-2017-02-02.csv',
#  'regional-global-weekly-2017-02-09.csv',
#  'regional-global-weekly-2017-02-16.csv',
#  'regional-global-weekly-2017-02-23.csv',
#  'regional-global-weekly-2017-03-02.csv',
#  'regional-global-weekly-2017-03-09.csv',
#  'regional-global-weekly-2017-03-16.csv',
#  'regional-global-weekly-2017-03-23.csv',
#  'regional-global-weekly-2017-03-30.csv',
#  'regional-global-weekly-2017-04-06.csv',
#  'regional-global-weekly-2017-04-13.csv',
#  'regional-global-weekly-2017-04-20.csv',
#  'regional-global-weekly-2017-04-27.csv',
#  'regional-global-weekly-2017-05-04.csv',
#  'regional-global-weekly-2017-05-11.csv',
#  'regional-global-weekly-2017-05-18.csv',
#  'regional-global-weekly-2017-05-25.csv',
#  'regional-global-weekly-2017-06-01.csv',
# ...

# %%
len(csv_files)
# Out:
# 332

# %%
df1 = pd.concat([pd.read_csv(file) for file in csv ], ignore_index=True)
df1
# Out:
#        rank                                   uri  \
# 0         1  spotify:track:5aAx2yezTd8zXrkmtKl66Z
# 1         2  spotify:track:7BKLCZ1jbUBVqRi2FVlTVw
# 2         3  spotify:track:5knuzwU65gJK7IF5yJsuaW
# 3         4  spotify:track:4pdPtRcBmOSQDlJ3Fk945m
# 4         5  spotify:track:3NdDpSvN911VPGivFlV5d0
# ...     ...                                   ...
# 66374   196  spotify:track:1JSTJqkT5qHq8MDJnJbRE1
# 66375   197  spotify:track:4SqWKzw0CbA05TGszDgMlc
# 66376   198  spotify:track:09mEdoA6zrmBPgTEN5qXmN
# 66377   199  spotify:track:7gRFDGEzF9UkBV233yv2dc
# 66378   200  spotify:track:3dYD57lRAUcMHufyqn9GcI
#
#                               artist_names  \
# 0                    The Weeknd, Daft Punk
# 1                 The Chainsmokers, Halsey
# 2      Clean Bandit, Sean Paul, Anne-Marie
# 3                  DJ Snake, Justin Bieber
# 4                       ZAYN, Taylor Swift
# ...                                    ...
# 66374                           The Police
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66379 entries, 0 to 66378
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   rank            66379 non-null  int64
#  1   uri             66379 non-null  object
#  2   artist_names    66379 non-null  object
#  3   track_name      66379 non-null  object
#  4   source          66379 non-null  object
#  5   peak_rank       66379 non-null  int64
#  6   previous_rank   66379 non-null  int64
#  7   weeks_on_chart  66379 non-null  int64
#  8   streams         66379 non-null  int64
# dtypes: int64(5), object(4)
# memory usage: 4.6+ MB

# %%
target_songs = df1['uri'].unique()
target_songs
# Out:
# array(['spotify:track:5aAx2yezTd8zXrkmtKl66Z',
#        'spotify:track:7BKLCZ1jbUBVqRi2FVlTVw',
#        'spotify:track:5knuzwU65gJK7IF5yJsuaW', ...,
#        'spotify:track:70LcF31zb1H0PyJoS1Sx1r',
#        'spotify:track:3IMuuBcKSeFqQSlF2XluA1',
#        'spotify:track:0WFryfbNKPXVtVQlz5dZ8H'], dtype=object)

# %%
ts_df = pd.DataFrame(target_songs, columns=['uri'])
print(ts_df)
# Out:
#                                        uri
# 0     spotify:track:5aAx2yezTd8zXrkmtKl66Z
# 1     spotify:track:7BKLCZ1jbUBVqRi2FVlTVw
# 2     spotify:track:5knuzwU65gJK7IF5yJsuaW
# 3     spotify:track:4pdPtRcBmOSQDlJ3Fk945m
# 4     spotify:track:3NdDpSvN911VPGivFlV5d0
# ...                                    ...
# 5923  spotify:track:456WNXWhDwYOSf5SpTuqxd
# 5924  spotify:track:4k7CNPArKLf4QuvGfMeHDk
# 5925  spotify:track:70LcF31zb1H0PyJoS1Sx1r
# 5926  spotify:track:3IMuuBcKSeFqQSlF2XluA1
# 5927  spotify:track:0WFryfbNKPXVtVQlz5dZ8H
#
# [5928 rows x 1 columns]

# %%
print(f'Songs to process: {len(target_songs)}')
# Out:
# Songs to process: 5928

# %%
# splitting dataframe by row index

#skenario 1
ts_df1 = ts_df.iloc[:1000,:]
ts_df2 = ts_df.iloc[1001:2000,:]
ts_df3 = ts_df.iloc[2001:3000,:]
ts_df4 = ts_df.iloc[3001:4000,:]
ts_df5 = ts_df.iloc[4001:5000,:]
ts_df6 = ts_df.iloc[5001:,:]

# %%
##TS_DF1
import random
import spotipy
import time
from spotipy.oauth2 import SpotifyClientCredentials #To access authorised Spotify data4
import pandas as pd

ts_df1['danceability'] = ''*ts_df1.shape[0]
ts_df1['duration_ms'] = ''*ts_df1.shape[0]
ts_df1['tempo'] = ''*ts_df1.shape[0]
ts_df1['valence'] = ''*ts_df1.shape[0]

for i in range(0,ts_df1.shape[0]):
  time.sleep(random.uniform(0, 5))
  URI = ts_df1.uri[i]
  features = sp.audio_features(URI)
  ts_df1.loc[i,'danceability'] = features[0]['danceability']
  ts_df1.loc[i,'duration_ms'] = features[0]['duration_ms']
  ts_df1.loc[i,'tempo'] = features[0]['tempo']
  ts_df1.loc[i,'valence'] = features[0]['valence']
  uri=0
# Out:
# /var/folders/np/6d2bz5c10v1102n7q036tbfw0000gn/T/ipykernel_15081/537911916.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ts_df1['danceability'] = ''*ts_df1.shape[0]
# /var/folders/np/6d2bz5c10v1102n7q036tbfw0000gn/T/ipykernel_15081/537911916.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ts_df1['duration_ms'] = ''*ts_df1.shape[0]
# /var/folders/np/6d2bz5c10v1102n7q036tbfw0000gn/T/ipykernel_15081/537911916.py:10: SettingWithCopyWarning:
# ...

# %%
ts_df2.reset_index(drop=True, inplace=True)

# %%
##TS_DF2
import spotipy
import time
from spotipy.oauth2 import SpotifyClientCredentials #To access authorised Spotify data4
import pandas as pd

ts_df2['danceability'] = ''*ts_df2.shape[0]
ts_df2['duration_ms'] = ''*ts_df2.shape[0]
ts_df2['tempo'] = ''*ts_df2.shape[0]
ts_df2['valence'] = ''*ts_df2.shape[0]

for i in range(0,ts_df2.shape[0]):
  time.sleep(random.uniform(0, 5))
  URI = ts_df2.uri[i]
  features = sp.audio_features(URI)
  ts_df2.loc[i,'danceability'] = features[0]['danceability']
  ts_df2.loc[i,'duration_ms'] = features[0]['duration_ms']
  ts_df2.loc[i,'tempo'] = features[0]['tempo']
  ts_df2.loc[i,'valence'] = features[0]['valence']
  uri=0
# Out:
# /var/folders/np/6d2bz5c10v1102n7q036tbfw0000gn/T/ipykernel_15081/3138488954.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ts_df2['danceability'] = ''*ts_df2.shape[0]
# /var/folders/np/6d2bz5c10v1102n7q036tbfw0000gn/T/ipykernel_15081/3138488954.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ts_df2['duration_ms'] = ''*ts_df2.shape[0]
# /var/folders/np/6d2bz5c10v1102n7q036tbfw0000gn/T/ipykernel_15081/3138488954.py:9: SettingWithCopyWarning:
# ...

# %%
ts_df3.reset_index(drop=True, inplace=True)

# %%
##TS_DF3
import spotipy
import time
from spotipy.oauth2 import SpotifyClientCredentials #To access authorised Spotify data4
import pandas as pd

ts_df3['danceability'] = ''*ts_df3.shape[0]
ts_df3['duration_ms'] = ''*ts_df3.shape[0]
ts_df3['tempo'] = ''*ts_df3.shape[0]
ts_df3['valence'] = ''*ts_df3.shape[0]

for i in range(0,ts_df3.shape[0]):
  time.sleep(random.uniform(0, 5))
  URI = ts_df3.uri[i]
  features = sp.audio_features(URI)
  ts_df3.loc[i,'danceability'] = features[0]['danceability']
  ts_df3.loc[i,'duration_ms'] = features[0]['duration_ms']
  ts_df3.loc[i,'tempo'] = features[0]['tempo']
  ts_df3.loc[i,'valence'] = features[0]['valence']
  uri=0
# Out:
# /var/folders/np/6d2bz5c10v1102n7q036tbfw0000gn/T/ipykernel_15081/3687294815.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ts_df3['danceability'] = ''*ts_df3.shape[0]
# /var/folders/np/6d2bz5c10v1102n7q036tbfw0000gn/T/ipykernel_15081/3687294815.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ts_df3['duration_ms'] = ''*ts_df3.shape[0]
# /var/folders/np/6d2bz5c10v1102n7q036tbfw0000gn/T/ipykernel_15081/3687294815.py:9: SettingWithCopyWarning:
# ...

# %%
ts_df4.reset_index(drop=True, inplace=True)

# %%
##TS_DF4
import spotipy
import time
from spotipy.oauth2 import SpotifyClientCredentials #To access authorised Spotify data4
import pandas as pd

ts_df4['danceability'] = ''*ts_df4.shape[0]
ts_df4['duration_ms'] = ''*ts_df4.shape[0]
ts_df4['tempo'] = ''*ts_df4.shape[0]
ts_df4['valence'] = ''*ts_df4.shape[0]

for i in range(0,ts_df4.shape[0]):
  time.sleep(random.uniform(0, 5))
  URI = ts_df4.uri[i]
  features = sp.audio_features(URI)
  ts_df4.loc[i,'danceability'] = features[0]['danceability']
  ts_df4.loc[i,'duration_ms'] = features[0]['duration_ms']
  ts_df4.loc[i,'tempo'] = features[0]['tempo']
  ts_df4.loc[i,'valence'] = features[0]['valence']
  uri=0
# Out:
# /var/folders/np/6d2bz5c10v1102n7q036tbfw0000gn/T/ipykernel_15081/2522444279.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ts_df4['danceability'] = ''*ts_df4.shape[0]
# /var/folders/np/6d2bz5c10v1102n7q036tbfw0000gn/T/ipykernel_15081/2522444279.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ts_df4['duration_ms'] = ''*ts_df4.shape[0]
# /var/folders/np/6d2bz5c10v1102n7q036tbfw0000gn/T/ipykernel_15081/2522444279.py:9: SettingWithCopyWarning:
# ...

# %%
ts_df5.reset_index(drop=True, inplace=True)

# %%
##TS_DF5
import spotipy
import time
from spotipy.oauth2 import SpotifyClientCredentials #To access authorised Spotify data4
import pandas as pd

ts_df5['danceability'] = ''*ts_df5.shape[0]
ts_df5['duration_ms'] = ''*ts_df5.shape[0]
ts_df5['tempo'] = ''*ts_df5.shape[0]
ts_df5['valence'] = ''*ts_df5.shape[0]

for i in range(0,ts_df5.shape[0]):
  time.sleep(random.uniform(0, 5))
  URI = ts_df5.uri[i]
  features = sp.audio_features(URI)
  ts_df5.loc[i,'danceability'] = features[0]['danceability']
  ts_df5.loc[i,'duration_ms'] = features[0]['duration_ms']
  ts_df5.loc[i,'tempo'] = features[0]['tempo']
  ts_df5.loc[i,'valence'] = features[0]['valence']
  uri=0
# Out:
# /var/folders/np/6d2bz5c10v1102n7q036tbfw0000gn/T/ipykernel_15081/2536771093.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ts_df5['danceability'] = ''*ts_df5.shape[0]
# /var/folders/np/6d2bz5c10v1102n7q036tbfw0000gn/T/ipykernel_15081/2536771093.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ts_df5['duration_ms'] = ''*ts_df5.shape[0]
# /var/folders/np/6d2bz5c10v1102n7q036tbfw0000gn/T/ipykernel_15081/2536771093.py:9: SettingWithCopyWarning:
# ...

# %%
ts_df6.reset_index(drop=True, inplace=True)

# %%
##TS_DF6
import spotipy
import time
from spotipy.oauth2 import SpotifyClientCredentials #To access authorised Spotify data4
import pandas as pd

ts_df6['danceability'] = ''*ts_df6.shape[0]
ts_df6['duration_ms'] = ''*ts_df6.shape[0]
ts_df6['tempo'] = ''*ts_df6.shape[0]
ts_df6['valence'] = ''*ts_df6.shape[0]

for i in range(0,ts_df6.shape[0]):
  time.sleep(random.uniform(0, 5))
  URI = ts_df6.uri[i]
  features = sp.audio_features(URI)
  ts_df6.loc[i,'danceability'] = features[0]['danceability']
  ts_df6.loc[i,'duration_ms'] = features[0]['duration_ms']
  ts_df6.loc[i,'tempo'] = features[0]['tempo']
  ts_df6.loc[i,'valence'] = features[0]['valence']
  uri=0
# Out:
# /var/folders/np/6d2bz5c10v1102n7q036tbfw0000gn/T/ipykernel_15081/1684763961.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ts_df6['danceability'] = ''*ts_df6.shape[0]
# /var/folders/np/6d2bz5c10v1102n7q036tbfw0000gn/T/ipykernel_15081/1684763961.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ts_df6['duration_ms'] = ''*ts_df6.shape[0]
# /var/folders/np/6d2bz5c10v1102n7q036tbfw0000gn/T/ipykernel_15081/1684763961.py:9: SettingWithCopyWarning:
# ...

# %%
with pd.ExcelWriter("ts_df.xlsx", engine="openpyxl") as writer:
    ts_df1.to_excel(writer,sheet_name="Sheet1")
    ts_df2.to_excel(writer,sheet_name="Sheet1", startrow=1001)
    ts_df3.to_excel(writer,sheet_name="Sheet1", startrow=2002)
    ts_df2.to_excel(writer,sheet_name="Sheet1", startrow=1001)
    ts_df3.to_excel(writer,sheet_name="Sheet1", startrow=2002)
    ts_df3.to_excel(writer,sheet_name="Sheet1", startrow=2002)

# %%
frames = [ts_df1,ts_df2,ts_df3,ts_df4,ts_df5,ts_df6]

# %%
new_target_songs=pd.concat(frames)
new_target_songs
# Out:
#                                       uri danceability duration_ms    tempo  \
# 0    spotify:track:5aAx2yezTd8zXrkmtKl66Z        0.681      230453  186.054
# 1    spotify:track:7BKLCZ1jbUBVqRi2FVlTVw        0.748      244960    95.01
# 2    spotify:track:5knuzwU65gJK7IF5yJsuaW         0.72      251088  101.965
# 3    spotify:track:4pdPtRcBmOSQDlJ3Fk945m        0.476      205947  199.864
# 4    spotify:track:3NdDpSvN911VPGivFlV5d0        0.735      245200  117.973
# ..                                    ...          ...         ...      ...
# 922  spotify:track:456WNXWhDwYOSf5SpTuqxd        0.501      252819  149.964
# 923  spotify:track:4k7CNPArKLf4QuvGfMeHDk        0.781      184267  175.956
# 924  spotify:track:70LcF31zb1H0PyJoS1Sx1r        0.515      238640   91.844
# 925  spotify:track:3IMuuBcKSeFqQSlF2XluA1        0.718      188075  142.986
# 926  spotify:track:0WFryfbNKPXVtVQlz5dZ8H        0.516       60720   56.829
#
#     valence energy
# 0     0.535  0.594
# 1     0.661
# ...

# %%
new_target_songs.reset_index(drop=True, inplace=True)

# %%
new_target_songs
# Out:
#                                        uri danceability duration_ms    tempo  \
# 0     spotify:track:5aAx2yezTd8zXrkmtKl66Z        0.681      230453  186.054
# 1     spotify:track:7BKLCZ1jbUBVqRi2FVlTVw        0.748      244960    95.01
# 2     spotify:track:5knuzwU65gJK7IF5yJsuaW         0.72      251088  101.965
# 3     spotify:track:4pdPtRcBmOSQDlJ3Fk945m        0.476      205947  199.864
# 4     spotify:track:3NdDpSvN911VPGivFlV5d0        0.735      245200  117.973
# ...                                    ...          ...         ...      ...
# 5918  spotify:track:456WNXWhDwYOSf5SpTuqxd        0.501      252819  149.964
# 5919  spotify:track:4k7CNPArKLf4QuvGfMeHDk        0.781      184267  175.956
# 5920  spotify:track:70LcF31zb1H0PyJoS1Sx1r        0.515      238640   91.844
# 5921  spotify:track:3IMuuBcKSeFqQSlF2XluA1        0.718      188075  142.986
# 5922  spotify:track:0WFryfbNKPXVtVQlz5dZ8H        0.516       60720   56.829
#
#      valence
# 0      0.535
# 1      0.661
# ...

# %%
new_target_songs.to_csv('songs_features.csv',index=False)

# %% [markdown]
# # Pre-Processing

# %%
df1
# Out:
#        rank                                   uri  \
# 0         1  spotify:track:5aAx2yezTd8zXrkmtKl66Z
# 1         2  spotify:track:7BKLCZ1jbUBVqRi2FVlTVw
# 2         3  spotify:track:5knuzwU65gJK7IF5yJsuaW
# 3         4  spotify:track:4pdPtRcBmOSQDlJ3Fk945m
# 4         5  spotify:track:3NdDpSvN911VPGivFlV5d0
# ...     ...                                   ...
# 66374   196  spotify:track:1JSTJqkT5qHq8MDJnJbRE1
# 66375   197  spotify:track:4SqWKzw0CbA05TGszDgMlc
# 66376   198  spotify:track:09mEdoA6zrmBPgTEN5qXmN
# 66377   199  spotify:track:7gRFDGEzF9UkBV233yv2dc
# 66378   200  spotify:track:3dYD57lRAUcMHufyqn9GcI
#
#                               artist_names  \
# 0                    The Weeknd, Daft Punk
# 1                 The Chainsmokers, Halsey
# 2      Clean Bandit, Sean Paul, Anne-Marie
# 3                  DJ Snake, Justin Bieber
# 4                       ZAYN, Taylor Swift
# ...                                    ...
# 66374                           The Police
# ...

# %%
merged_data=df1.merge(new_target_songs, on='uri', how='left')

# %%
merged_data.to_csv('merged_data.csv',index=False)

# %%
merged_data
# Out:
#        rank                                   uri  \
# 0         1  spotify:track:5aAx2yezTd8zXrkmtKl66Z
# 1         2  spotify:track:7BKLCZ1jbUBVqRi2FVlTVw
# 2         3  spotify:track:5knuzwU65gJK7IF5yJsuaW
# 3         4  spotify:track:4pdPtRcBmOSQDlJ3Fk945m
# 4         5  spotify:track:3NdDpSvN911VPGivFlV5d0
# ...     ...                                   ...
# 66374   196  spotify:track:1JSTJqkT5qHq8MDJnJbRE1
# 66375   197  spotify:track:4SqWKzw0CbA05TGszDgMlc
# 66376   198  spotify:track:09mEdoA6zrmBPgTEN5qXmN
# 66377   199  spotify:track:7gRFDGEzF9UkBV233yv2dc
# 66378   200  spotify:track:3dYD57lRAUcMHufyqn9GcI
#
#                               artist_names  \
# 0                    The Weeknd, Daft Punk
# 1                 The Chainsmokers, Halsey
# 2      Clean Bandit, Sean Paul, Anne-Marie
# 3                  DJ Snake, Justin Bieber
# 4                       ZAYN, Taylor Swift
# ...                                    ...
# 66374                           The Police
# ...

# %%
mood_features= 'danceability duration_ms tempo valence'.split()

# %%
merged_lite= merged_data[mood_features+['uri']]
merged_lite.head()
# Out:
#   danceability duration_ms    tempo valence  \
# 0        0.681      230453  186.054   0.535
# 1        0.748      244960    95.01   0.661
# 2         0.72      251088  101.965   0.742
# 3        0.476      205947  199.864   0.142
# 4        0.735      245200  117.973  0.0862
#
#                                     uri
# 0  spotify:track:5aAx2yezTd8zXrkmtKl66Z
# 1  spotify:track:7BKLCZ1jbUBVqRi2FVlTVw
# 2  spotify:track:5knuzwU65gJK7IF5yJsuaW
# 3  spotify:track:4pdPtRcBmOSQDlJ3Fk945m
# 4  spotify:track:3NdDpSvN911VPGivFlV5d0

# %%
merged_lite.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 66379 entries, 0 to 66378
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   danceability  66300 non-null  object
#  1   duration_ms   66300 non-null  object
#  2   tempo         66300 non-null  object
#  3   valence       66300 non-null  object
#  4   uri           66379 non-null  object
# dtypes: object(5)
# memory usage: 3.0+ MB

# %%
merged_lite = merged_lite.astype({'danceability':'float','duration_ms':'float',
                                  'tempo':'float','valence':'float'})

# %%
merged_lite.describe()
# Out:
#        danceability    duration_ms         tempo       valence
# count  66300.000000   66300.000000  66300.000000  66300.000000
# mean       0.688549  206190.504842    120.822939      0.505021
# std        0.138358   43213.651017     29.235294      0.224860
# min        0.150000   30133.000000     46.718000      0.032000
# 25%        0.601000  178613.000000     97.001000      0.336000
# 50%        0.707000  203201.000000    117.973000      0.497000
# 75%        0.789000  228787.000000    140.025000      0.679000
# max        0.985000  690732.000000    212.117000      0.982000

# %%
#Rata-rata dibagi 200 karena hanya ada 200 lagu per minggu
time_series_unindexed = merged_lite.groupby(np.arange(len(merged_lite))//200).mean()

# %%
time_series_unindexed
# Out:
#      danceability    duration_ms       tempo   valence
# 0        0.676175  224062.520000  119.492000  0.505371
# 1        0.676660  224953.800000  118.911400  0.492766
# 2        0.678515  222356.310000  121.031995  0.490410
# 3        0.675180  223211.170000  120.914100  0.482200
# 4        0.682140  223758.000000  120.833820  0.485920
# ..            ...            ...         ...       ...
# 327      0.669585  202541.385000  123.700665  0.514779
# 328      0.661700  202339.700000  123.951925  0.504533
# 329      0.663800  202114.070000  124.696265  0.510401
# 330      0.662735  203637.450000  126.035915  0.505849
# 331      0.659877  201448.089385  124.370430  0.491531
#
# [332 rows x 4 columns]

# %%
time_series_unindexed.to_csv('time_series_unindexed.csv',index=False)
